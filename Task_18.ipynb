# %% [markdown]
# <a href="https://colab.research.google.com/github/wankhadearpit21-pixel/Python-Project/blob/main/Task_18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('ford_car_dataset.csv')

# %%
df.head(10)
# Out:
#     model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0  Fiesta  2017  12000    Automatic    15944   Petrol  150  57.7         1.0
# 1   Focus  2018  14000       Manual     9083   Petrol  150  57.7         1.0
# 2   Focus  2017  13000       Manual    12456   Petrol  150  57.7         1.0
# 3  Fiesta  2019  17500       Manual    10460   Petrol  145  40.3         1.5
# 4  Fiesta  2019  16500    Automatic     1482   Petrol  145  48.7         1.0
# 5  Fiesta  2015  10500       Manual    35432   Petrol  145  47.9         1.6
# 6    Puma  2019  22500       Manual     2029   Petrol  145  50.4         1.0
# 7  Fiesta  2017   9000       Manual    13054   Petrol  145  54.3         1.2
# 8    Kuga  2019  25500    Automatic     6894   Diesel  145  42.2         2.0
# 9   Focus  2018  10000       Manual    48141   Petrol  145  61.4         1.0

# %%
df.tail(5)
# Out:
#        model  year  price transmission  mileage fuelType  tax   mpg  \
# 17961  B-MAX  2017   8999       Manual    16700   Petrol  150  47.1
# 17962  B-MAX  2014   7499       Manual    40700   Petrol   30  57.7
# 17963  Focus  2015   9999       Manual     7010   Diesel   20  67.3
# 17964     KA  2018   8299       Manual     5007   Petrol  145  57.7
# 17965  Focus  2015   8299       Manual     5007   Petrol   22  57.7
#
#        engineSize
# 17961         1.4
# 17962         1.0
# 17963         1.6
# 17964         1.2
# 17965         1.0

# %%
df.shape
# Out:
# (17966, 9)

# %%
df.dtypes
# Out:
# model            object
# year              int64
# price             int64
# transmission     object
# mileage           int64
# fuelType         object
# tax               int64
# mpg             float64
# engineSize      float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# model           0
# year            0
# price           0
# transmission    0
# mileage         0
# fuelType        0
# tax             0
# mpg             0
# engineSize      0
# dtype: int64

# %%
df =df.drop_duplicates()

# %%
print("After Dropping Duplicate Values")
df.duplicated().sum()
# Out:
# After Dropping Duplicate Values
# np.int64(0)

# %%
df.describe()
# Out:
#                year         price        mileage           tax           mpg  \
# count  17812.000000  17812.000000   17812.000000  17812.000000  17812.000000
# mean    2016.862396  12269.556310   23381.146362    113.315012     57.908696
# std        2.052039   4736.285417   19419.011045     62.034603     10.132696
# min     1996.000000    495.000000       1.000000      0.000000     20.800000
# 25%     2016.000000   8999.000000   10000.000000     30.000000     52.300000
# 50%     2017.000000  11288.000000   18277.000000    145.000000     58.900000
# 75%     2018.000000  15295.000000   31098.500000    145.000000     65.700000
# max     2060.000000  54995.000000  177644.000000    580.000000    201.800000
#
#          engineSize
# count  17812.000000
# mean       1.350623
# std        0.432581
# min        0.000000
# 25%        1.000000
# 50%        1.200000
# 75%        1.500000
# max        5.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.subplot(2,2,1)
sns.histplot(df['price'])
plt.subplot(2,2,2)
sns.histplot(df['mileage'])
plt.subplot(2,2,3)
sns.histplot(df['year'])
plt.subplot(2,2,4)
sns.histplot(df['mpg'])
plt.tight_layout()

# %%
plt.subplot(2,2,1)
sns.countplot(data=df,x = 'fuelType')
plt.subplot(2,2,2)
sns.countplot(data=df,x = 'transmission')
plt.subplot(2,2,3)
sns.countplot(data=df,x = 'model')
plt.tight_layout()

# %%
sns.heatmap(df.corr(numeric_only=True),annot= True)
# Out:
# <Axes: >

# %%
# Input Features :- model,transmission,fueltype,engineSize
# Output Features :- Price

# If we think to build a car price predication model then the input and output will be above

# %%
print("Data set Before One hot Encoding :")
df.head(2)
# Out:
# Data set Before One hot Encoding :
#     model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0  Fiesta  2017  12000    Automatic    15944   Petrol  150  57.7         1.0
# 1   Focus  2018  14000       Manual     9083   Petrol  150  57.7         1.0

# %%
encoded_df = pd.get_dummies(df)

# %%
print("Data sety After one hot Encoding :-")
encoded_df.head(2)
# Out:
# Data sety After one hot Encoding :-
#    year  price  mileage  tax   mpg  engineSize  model_B-MAX  model_C-MAX  \
# 0  2017  12000    15944  150  57.7         1.0        False        False
# 1  2018  14000     9083  150  57.7         1.0        False        False
#
#    model_EcoSport  model_Edge  ...  model_Tourneo Custom  \
# 0           False       False  ...                 False
# 1           False       False  ...                 False
#
#    model_Transit Tourneo  transmission_Automatic  transmission_Manual  \
# 0                  False                    True                False
# 1                  False                   False                 True
#
#    transmission_Semi-Auto  fuelType_Diesel  fuelType_Electric  \
# 0                   False            False              False
# 1                   False            False              False
#
#    fuelType_Hybrid  fuelType_Other  fuelType_Petrol
# 0            False           False             True
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_df = pd.DataFrame(scaler.fit_transform(encoded_df),columns=encoded_df.columns)

# %%
scaled_df.head()
# Out:
#        year     price   mileage       tax       mpg  engineSize  model_B-MAX  \
# 0  0.067059 -0.056915 -0.382994  0.591380 -0.020597   -0.810561    -0.141575
# 1  0.554393  0.365369 -0.736317  0.591380 -0.020597   -0.810561    -0.141575
# 2  0.067059  0.154227 -0.562616  0.591380 -0.020597   -0.810561    -0.141575
# 3  1.041726  1.104366 -0.665405  0.510777 -1.737858    0.345325    -0.141575
# 4  1.041726  0.893224 -1.127749  0.510777 -0.908836   -0.810561    -0.141575
#
#    model_C-MAX  model_EcoSport  model_Edge  ...  model_Tourneo Custom  \
# 0    -0.177155       -0.259896   -0.107903  ...             -0.062361
# 1    -0.177155       -0.259896   -0.107903  ...             -0.062361
# 2    -0.177155       -0.259896   -0.107903  ...             -0.062361
# 3    -0.177155       -0.259896   -0.107903  ...             -0.062361
# 4    -0.177155       -0.259896   -0.107903  ...             -0.062361
#
#    model_Transit Tourneo  transmission_Automatic  transmission_Manual  \
# ...

# %%
df = pd.read_csv('ford_car_dataset.csv')

# %%
df.head()
# Out:
#     model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0  Fiesta  2017  12000    Automatic    15944   Petrol  150  57.7         1.0
# 1   Focus  2018  14000       Manual     9083   Petrol  150  57.7         1.0
# 2   Focus  2017  13000       Manual    12456   Petrol  150  57.7         1.0
# 3  Fiesta  2019  17500       Manual    10460   Petrol  145  40.3         1.5
# 4  Fiesta  2019  16500    Automatic     1482   Petrol  145  48.7         1.0

# %%
print("Before Removing Duplicates :")
df.duplicated().sum()
# Out:
# Before Removing Duplicates :
# np.int64(154)

# %%
new_df = df.drop_duplicates()

# %%
print("After removing Duplicates :")
new_df.duplicated().sum()
# Out:
# After removing Duplicates :
# np.int64(0)

# %%
plt.subplot(1,2,1)
sns.histplot(new_df['price'])
plt.subplot(1,2,2)
sns.histplot(new_df['mileage'])
plt.tight_layout()

# %%
plt.subplot(1,2,1)
sns.countplot(data = new_df,x='fuelType')
plt.subplot(1,2,2)
sns.countplot(data=new_df,x='transmission')
plt.tight_layout()

# %%
sns.heatmap(new_df.corr(numeric_only=True),annot =True)
# Out:
# <Axes: >

# %%
encoded_df = pd.get_dummies(df)
encoded_df.head()
# Out:
#    year  price  mileage  tax   mpg  engineSize  model_B-MAX  model_C-MAX  \
# 0  2017  12000    15944  150  57.7         1.0        False        False
# 1  2018  14000     9083  150  57.7         1.0        False        False
# 2  2017  13000    12456  150  57.7         1.0        False        False
# 3  2019  17500    10460  145  40.3         1.5        False        False
# 4  2019  16500     1482  145  48.7         1.0        False        False
#
#    model_EcoSport  model_Edge  ...  model_Tourneo Custom  \
# 0           False       False  ...                 False
# 1           False       False  ...                 False
# 2           False       False  ...                 False
# 3           False       False  ...                 False
# 4           False       False  ...                 False
#
#    model_Transit Tourneo  transmission_Automatic  transmission_Manual  \
# 0                  False                    True                False
# ...

# %%
scaler = StandardScaler()
Scaled_df = pd.DataFrame(scaler.fit_transform(encoded_df),columns = encoded_df.columns)
Scaled_df.head()
# Out:
#        year     price   mileage       tax       mpg  engineSize  model_B-MAX  \
# 0  0.065128 -0.058959 -0.380998  0.591358 -0.020442   -0.811386    -0.141978
# 1  0.552866  0.362875 -0.733359  0.591358 -0.020442   -0.811386    -0.141978
# 2  0.065128  0.151958 -0.560132  0.591358 -0.020442   -0.811386    -0.141978
# 3  1.040605  1.101082 -0.662640  0.510727 -1.738890    0.345070    -0.141978
# 4  1.040605  0.890166 -1.123724  0.510727 -0.909294   -0.811386    -0.141978
#
#    model_C-MAX  model_EcoSport  model_Edge  ...  model_Tourneo Custom  \
# 0    -0.176538       -0.260658   -0.108227  ...             -0.062092
# 1    -0.176538       -0.260658   -0.108227  ...             -0.062092
# 2    -0.176538       -0.260658   -0.108227  ...             -0.062092
# 3    -0.176538       -0.260658   -0.108227  ...             -0.062092
# 4    -0.176538       -0.260658   -0.108227  ...             -0.062092
#
#    model_Transit Tourneo  transmission_Automatic  transmission_Manual  \
# ...
