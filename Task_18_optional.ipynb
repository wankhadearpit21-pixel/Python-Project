# %% [markdown]
# <a href="https://colab.research.google.com/github/wankhadearpit21-pixel/Python-Project/blob/main/Task_18_optional.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
import warnings
warnings.filterwarnings("ignore")

# %%
from google.colab import files
upload = files.upload()
# Out:
#      <input type="file" id="files-ddb543de-69ff-491f-8f6a-ab725464a055" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ddb543de-69ff-491f-8f6a-ab725464a055">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
file_path = '/content/insurance.csv'
df = pd.read_csv(file_path)

# %%
df.tail()
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 1333   50    male  31.0         3     no  northwest  10600.55
# 1334   18  female  31.9         0     no  northeast   2205.98
# 1335   18  female  36.9         0     no  southeast   1629.83
# 1336   21  female  25.8         0     no  southwest   2007.95
# 1337   61  female  29.1         0    yes  northwest  29141.36

# %%
df.shape
# Out:
# (1338, 7)

# %%
df.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# expenses    float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   expenses  1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.describe()
# Out:
#                age          bmi     children      expenses
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.665471     1.094918  13270.422414
# std      14.049960     6.098382     1.205493  12110.011240
# min      18.000000    16.000000     0.000000   1121.870000
# 25%      27.000000    26.300000     0.000000   4740.287500
# 50%      39.000000    30.400000     1.000000   9382.030000
# 75%      51.000000    34.700000     2.000000  16639.915000
# max      64.000000    53.100000     5.000000  63770.430000

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# expenses    0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1333    False
# 1334    False
# 1335    False
# 1336    False
# 1337    False
# Length: 1338, dtype: bool

# %%
df = df.drop_duplicates()

# %%
df.head()
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86

# %%
plt.hist(df['bmi'])
# Out:
# (array([ 30., 129., 232., 318., 288., 195.,  96.,  32.,  14.,   3.]),
#  array([16.  , 19.71, 23.42, 27.13, 30.84, 34.55, 38.26, 41.97, 45.68,
#         49.39, 53.1 ]),
#  <BarContainer object of 10 artists>)

# %%
sns.histplot(df['expenses'])
# Out:
# <Axes: xlabel='expenses', ylabel='Count'>

# %%
sns.countplot(data =df,x =df['region'])
# Out:
# <Axes: xlabel='region', ylabel='count'>

# %%
sns.scatterplot(x=df['expenses'],y=df['age'],data =df)
# Out:
# <Axes: xlabel='expenses', ylabel='age'>

# %%
sns.heatmap(df.corr(numeric_only =True),annot = True)
# Out:
# <Axes: >

# %%
sns.boxplot(x=df['children'],y=df['expenses'],data=df)
# Out:
# <Axes: xlabel='children', ylabel='expenses'>

# %%
encoded = pd.get_dummies(df)

# %%
encoded.head()
# Out:
#    age   bmi  children  expenses  sex_female  sex_male  smoker_no  smoker_yes  \
# 0   19  27.9         0  16884.92        True     False      False        True
# 1   18  33.8         1   1725.55       False      True       True       False
# 2   28  33.0         3   4449.46       False      True       True       False
# 3   33  22.7         0  21984.47       False      True       True       False
# 4   32  28.9         0   3866.86       False      True       True       False
#
#    region_northeast  region_northwest  region_southeast  region_southwest
# 0             False             False             False              True
# 1             False             False              True             False
# 2             False             False              True             False
# 3             False              True             False             False
# 4             False              True             False             False

# %%
scaler = StandardScaler()
scaled = pd.DataFrame(scaler.fit_transform(encoded),columns = encoded.columns)

# %%
scaled.head()
# Out:
#         age       bmi  children  expenses  sex_female  sex_male  smoker_no  \
# 0 -1.440418 -0.453484 -0.909234  0.297856    1.009771 -1.009771  -1.969660
# 1 -1.511647  0.513986 -0.079442 -0.954381   -0.990324  0.990324   0.507702
# 2 -0.799350  0.382803  1.580143 -0.729373   -0.990324  0.990324   0.507702
# 3 -0.443201 -1.306169 -0.909234  0.719104   -0.990324  0.990324   0.507702
# 4 -0.514431 -0.289506 -0.909234 -0.777498   -0.990324  0.990324   0.507702
#
#    smoker_yes  region_northeast  region_northwest  region_southeast  \
# 0    1.969660         -0.565546         -0.565546         -0.611638
# 1   -0.507702         -0.565546         -0.565546          1.634955
# 2   -0.507702         -0.565546         -0.565546          1.634955
# 3   -0.507702         -0.565546          1.768203         -0.611638
# 4   -0.507702         -0.565546          1.768203         -0.611638
#
#    region_southwest
# 0          1.764609
# 1         -0.566698
# 2         -0.566698
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
import warnings
warnings.filterwarnings("ignore")

# %%
from google.colab import files
upload = files.upload()
# Out:
#      <input type="file" id="files-8fd46b8a-cae4-40b3-a8ae-5b4f23e42d1c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8fd46b8a-cae4-40b3-a8ae-5b4f23e42d1c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df.head()
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86

# %%
df.tail()
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 1333   50    male  31.0         3     no  northwest  10600.55
# 1334   18  female  31.9         0     no  northeast   2205.98
# 1335   18  female  36.9         0     no  southeast   1629.83
# 1336   21  female  25.8         0     no  southwest   2007.95
# 1337   61  female  29.1         0    yes  northwest  29141.36

# %%
df.shape
# Out:
# (1337, 7)

# %%
df.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# expenses    float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1337 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1337 non-null   int64
#  1   sex       1337 non-null   object
#  2   bmi       1337 non-null   float64
#  3   children  1337 non-null   int64
#  4   smoker    1337 non-null   object
#  5   region    1337 non-null   object
#  6   expenses  1337 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 83.6+ KB

# %%
df.describe()
# Out:
#                age          bmi     children      expenses
# count  1337.000000  1337.000000  1337.000000   1337.000000
# mean     39.222139    30.665520     1.095737  13279.121638
# std      14.044333     6.100664     1.205571  12110.359657
# min      18.000000    16.000000     0.000000   1121.870000
# 25%      27.000000    26.300000     0.000000   4746.340000
# 50%      39.000000    30.400000     1.000000   9386.160000
# 75%      51.000000    34.700000     2.000000  16657.720000
# max      64.000000    53.100000     5.000000  63770.430000

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# expenses    0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1333    False
# 1334    False
# 1335    False
# 1336    False
# 1337    False
# Length: 1337, dtype: bool

# %%
df = df.drop_duplicates()

# %%
df.head()
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86

# %%
plt.hist(df['bmi'])
# Out:
# (array([ 30., 129., 232., 318., 288., 195.,  96.,  32.,  14.,   3.]),
#  array([16.  , 19.71, 23.42, 27.13, 30.84, 34.55, 38.26, 41.97, 45.68,
#         49.39, 53.1 ]),
#  <BarContainer object of 10 artists>)

# %%
sns.histplot(df['sex'])
# Out:
# <Axes: xlabel='sex', ylabel='Count'>

# %%
sns.countplot(data =df,x =df['smoker'])
plt.xticks(rotation =45)
# Out:
# ([0, 1], [Text(0, 0, 'yes'), Text(1, 0, 'no')])

# %%
sns.scatterplot(x=df['age'],y=df['bmi'],data=df)
# Out:
# <Axes: xlabel='age', ylabel='bmi'>

# %%
sns.heatmap(df.corr(numeric_only=True))
# Out:
# <Axes: >

# %%
df.head()
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86

# %%
sns.boxplot(x =df['region'],y=df['bmi'],data =df)
# Out:
# <Axes: xlabel='region', ylabel='bmi'>

# %%
encoded =pd.get_dummies(df)

# %%
encoded.head()
# Out:
#    age   bmi  children  expenses  sex_female  sex_male  smoker_no  smoker_yes  \
# 0   19  27.9         0  16884.92        True     False      False        True
# 1   18  33.8         1   1725.55       False      True       True       False
# 2   28  33.0         3   4449.46       False      True       True       False
# 3   33  22.7         0  21984.47       False      True       True       False
# 4   32  28.9         0   3866.86       False      True       True       False
#
#    region_northeast  region_northwest  region_southeast  region_southwest
# 0             False             False             False              True
# 1             False             False              True             False
# 2             False             False              True             False
# 3             False              True             False             False
# 4             False              True             False             False

# %%
encoded.shape
# Out:
# (1337, 12)

# %%
scalar = StandardScaler()
scaled = pd.DataFrame(scaler.fit_transform(encoded),columns =encoded.columns)

# %%
scaled.head()
# Out:
#         age       bmi  children  expenses  sex_female  sex_male  smoker_no  \
# 0 -1.440418 -0.453484 -0.909234  0.297856    1.009771 -1.009771  -1.969660
# 1 -1.511647  0.513986 -0.079442 -0.954381   -0.990324  0.990324   0.507702
# 2 -0.799350  0.382803  1.580143 -0.729373   -0.990324  0.990324   0.507702
# 3 -0.443201 -1.306169 -0.909234  0.719104   -0.990324  0.990324   0.507702
# 4 -0.514431 -0.289506 -0.909234 -0.777498   -0.990324  0.990324   0.507702
#
#    smoker_yes  region_northeast  region_northwest  region_southeast  \
# 0    1.969660         -0.565546         -0.565546         -0.611638
# 1   -0.507702         -0.565546         -0.565546          1.634955
# 2   -0.507702         -0.565546         -0.565546          1.634955
# 3   -0.507702         -0.565546          1.768203         -0.611638
# 4   -0.507702         -0.565546          1.768203         -0.611638
#
#    region_southwest
# 0          1.764609
# 1         -0.566698
# 2         -0.566698
# ...

# %%
scaled.shape
# Out:
# (1337, 12)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
import warnings
warnings.filterwarnings("ignore")

# %%
from google.colab import files
upload = files.upload()
# Out:
#      <input type="file" id="files-529e4bde-1a4c-4290-98f8-67c26298ac45" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-529e4bde-1a4c-4290-98f8-67c26298ac45">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
file_path ='/content/data_center_hybrid.csv'
df =pd.read_csv(file_path)

# %%
df.head()
# Out:
#    Year  Facility_ID               Facility_Name Owner_Company    City  \
# 0  2019  DC-D2763E00  NAP de las Americas Madrid     Terremark  Madrid
# 1  2020  DC-D2763E00  NAP de las Americas Madrid     Terremark  Madrid
# 2  2021  DC-D2763E00  NAP de las Americas Madrid     Terremark  Madrid
# 3  2022  DC-D2763E00  NAP de las Americas Madrid     Terremark  Madrid
# 4  2023  DC-D2763E00  NAP de las Americas Madrid     Terremark  Madrid
#
#   Country        Facility_Type  Estimated_Capacity_MW    PUE  \
# 0   Spain  Enterprise/Standard                   6.24  1.975
# 1   Spain  Enterprise/Standard                   6.36  1.967
# 2   Spain  Enterprise/Standard                   6.47  1.928
# 3   Spain  Enterprise/Standard                   6.59  1.897
# 4   Spain  Enterprise/Standard                   6.70  1.869
#
#   Cooling_System_Type  WUE_L_per_kWh  Daily_Electricity_Usage_MWh  \
# 0         Evaporative          1.481                       183.62
# ...

# %%
df.tail()
# Out:
#         Year  Facility_ID       Facility_Name  \
# 126765  2021  DC-31D8B15E  ICS_DataCenter_216
# 126766  2022  DC-31D8B15E  ICS_DataCenter_216
# 126767  2023  DC-31D8B15E  ICS_DataCenter_216
# 126768  2024  DC-31D8B15E  ICS_DataCenter_216
# 126769  2025  DC-31D8B15E  ICS_DataCenter_216
#
#                                             Owner_Company     City  Country  \
# 126765  ICS BİLİŞİM TEKNOLOJİLERİ DANIŞMANLIK HİZMETLE...  Unknown  Türkiye
# 126766  ICS BİLİŞİM TEKNOLOJİLERİ DANIŞMANLIK HİZMETLE...  Unknown  Türkiye
# 126767  ICS BİLİŞİM TEKNOLOJİLERİ DANIŞMANLIK HİZMETLE...  Unknown  Türkiye
# 126768  ICS BİLİŞİM TEKNOLOJİLERİ DANIŞMANLIK HİZMETLE...  Unknown  Türkiye
# 126769  ICS BİLİŞİM TEKNOLOJİLERİ DANIŞMANLIK HİZMETLE...  Unknown  Türkiye
#
#               Facility_Type  Estimated_Capacity_MW    PUE Cooling_System_Type  \
# 126765  Enterprise/Standard                  14.51  1.495         Evaporative
# ...

# %%
df.shape
# Out:
# (126770, 14)

# %%
df.dtypes
# Out:
# Year                               int64
# Facility_ID                       object
# Facility_Name                     object
# Owner_Company                     object
# City                              object
# Country                           object
# Facility_Type                     object
# Estimated_Capacity_MW            float64
# PUE                              float64
# Cooling_System_Type               object
# WUE_L_per_kWh                    float64
# Daily_Electricity_Usage_MWh      float64
# Daily_Water_Usage_Gallons        float64
# Surrounding_Water_Stress_Tier     object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126770 entries, 0 to 126769
# Data columns (total 14 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Year                           126770 non-null  int64
#  1   Facility_ID                    126770 non-null  object
#  2   Facility_Name                  126770 non-null  object
#  3   Owner_Company                  126770 non-null  object
#  4   City                           126770 non-null  object
#  5   Country                        126770 non-null  object
#  6   Facility_Type                  126770 non-null  object
#  7   Estimated_Capacity_MW          126770 non-null  float64
#  8   PUE                            126770 non-null  float64
#  9   Cooling_System_Type            126770 non-null  object
#  10  WUE_L_per_kWh                  126770 non-null  float64
#  11  Daily_Electricity_Usage_MWh    126770 non-null  float64
# ...

# %%
df.describe()
# Out:
#                 Year  Estimated_Capacity_MW            PUE  WUE_L_per_kWh  \
# count  126770.000000          126770.000000  126770.000000  126770.000000
# mean     2022.000000              23.075117       1.637746       0.820596
# std         2.000008              45.847195       0.190833       0.925481
# min      2019.000000               1.000000       1.057000       0.001000
# 25%      2020.000000               5.450000       1.518000       0.139000
# 50%      2022.000000               9.870000       1.643000       0.232000
# 75%      2024.000000              14.180000       1.787000       1.654000
# max      2025.000000             562.890000       2.000000       3.000000
#
#        Daily_Electricity_Usage_MWh  Daily_Water_Usage_Gallons
# count                126770.000000               1.267700e+05
# mean                    605.222368               1.312182e+05
# std                    1040.061940               3.979629e+05
# ...

# %%
df.isnull().sum()
# Out:
# Year                             0
# Facility_ID                      0
# Facility_Name                    0
# Owner_Company                    0
# City                             0
# Country                          0
# Facility_Type                    0
# Estimated_Capacity_MW            0
# PUE                              0
# Cooling_System_Type              0
# WUE_L_per_kWh                    0
# Daily_Electricity_Usage_MWh      0
# Daily_Water_Usage_Gallons        0
# Surrounding_Water_Stress_Tier    0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 126765    False
# 126766    False
# 126767    False
# 126768    False
# 126769    False
# Length: 126770, dtype: bool

# %%
df =df.drop_duplicates()

# %%
df.head()
# Out:
#    Year  Facility_ID               Facility_Name Owner_Company    City  \
# 0  2019  DC-D2763E00  NAP de las Americas Madrid     Terremark  Madrid
# 1  2020  DC-D2763E00  NAP de las Americas Madrid     Terremark  Madrid
# 2  2021  DC-D2763E00  NAP de las Americas Madrid     Terremark  Madrid
# 3  2022  DC-D2763E00  NAP de las Americas Madrid     Terremark  Madrid
# 4  2023  DC-D2763E00  NAP de las Americas Madrid     Terremark  Madrid
#
#   Country        Facility_Type  Estimated_Capacity_MW    PUE  \
# 0   Spain  Enterprise/Standard                   6.24  1.975
# 1   Spain  Enterprise/Standard                   6.36  1.967
# 2   Spain  Enterprise/Standard                   6.47  1.928
# 3   Spain  Enterprise/Standard                   6.59  1.897
# 4   Spain  Enterprise/Standard                   6.70  1.869
#
#   Cooling_System_Type  WUE_L_per_kWh  Daily_Electricity_Usage_MWh  \
# 0         Evaporative          1.481                       183.62
# ...

# %%
plt.hist(df['PUE'])
plt.xticks(rotation =90)
# Out:
# (array([1. , 1.2, 1.4, 1.6, 1.8, 2. , 2.2]),
#  [Text(1.0, 0, '1.0'),
#   Text(1.2, 0, '1.2'),
#   Text(1.4, 0, '1.4'),
#   Text(1.6, 0, '1.6'),
#   Text(1.8, 0, '1.8'),
#   Text(2.0, 0, '2.0'),
#   Text(2.2, 0, '2.2')])

# %%
sns.histplot(df['Facility_Type'])
# Out:
# <Axes: xlabel='Facility_Type', ylabel='Count'>

# %%
sns.countplot(data=df,x=df['Year'])
# Out:
# <Axes: xlabel='Year', ylabel='count'>

# %%
sns.scatterplot(x =df['Estimated_Capacity_MW'],y=df['PUE'])
# Out:
# <Axes: xlabel='Estimated_Capacity_MW', ylabel='PUE'>

# %%
sns.heatmap(df.corr(numeric_only =True),annot=True)
# Out:
# <Axes: >

# %%
df.head()
# Out:
#    Year  Facility_ID               Facility_Name Owner_Company    City  \
# 0  2019  DC-D2763E00  NAP de las Americas Madrid     Terremark  Madrid
# 1  2020  DC-D2763E00  NAP de las Americas Madrid     Terremark  Madrid
# 2  2021  DC-D2763E00  NAP de las Americas Madrid     Terremark  Madrid
# 3  2022  DC-D2763E00  NAP de las Americas Madrid     Terremark  Madrid
# 4  2023  DC-D2763E00  NAP de las Americas Madrid     Terremark  Madrid
#
#   Country        Facility_Type  Estimated_Capacity_MW    PUE  \
# 0   Spain  Enterprise/Standard                   6.24  1.975
# 1   Spain  Enterprise/Standard                   6.36  1.967
# 2   Spain  Enterprise/Standard                   6.47  1.928
# 3   Spain  Enterprise/Standard                   6.59  1.897
# 4   Spain  Enterprise/Standard                   6.70  1.869
#
#   Cooling_System_Type  WUE_L_per_kWh  Daily_Electricity_Usage_MWh  \
# 0         Evaporative          1.481                       183.62
# ...

# %%
df.drop(columns ='Year',inplace =True)

# %%
encoded =pd.get_dummies(df)

# %%
encoded.head()
# Out:
#    Estimated_Capacity_MW    PUE  WUE_L_per_kWh  Daily_Electricity_Usage_MWh  \
# 0                   6.24  1.975          1.481                       183.62
# 1                   6.36  1.967          1.459                       254.34
# 2                   6.47  1.928          1.450                       266.85
# 3                   6.59  1.897          1.413                       199.14
# 4                   6.70  1.869          1.389                       225.94
#
#    Daily_Water_Usage_Gallons  Facility_ID_DC-0006E5D5  \
# 0                   36362.94                    False
# 1                   49833.60                    False
# 2                   53026.35                    False
# 3                   39198.30                    False
# 4                   44366.48                    False
#
#    Facility_ID_DC-00072FB6  Facility_ID_DC-00091E2F  Facility_ID_DC-00108D19  \
# 0                    False                    False                    False
# ...

# %%
encoded.shape
# Out:
# (126770, 41447)
